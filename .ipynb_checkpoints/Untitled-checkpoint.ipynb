# %% [markdown]
# Welcome to Kilian's Commodity Global Market Analysis. I strongly invite you to go through all the differents code and graph in order to have a real understanding of the market current market dynamic
# Since my objective is just to do a Market Analysis, the forecasting methods that I will use are relatively basic. I usually prefer to use more accurate and complex models but here the goal is juste to have a global perspective of the market.
# You can find more complex models in the Github file

# %%
import yfinance as yf
import pandas as pd


pd.set_option('display.max_colwidth', None) #tells pandas to not limit the width of column content when printing DataFrames
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

oil = yf.Ticker('CL=F')
df_oil = oil.history(period = '5y')
display(df_oil.head())
# Out:
#                                 Open       High        Low  Close  Volume  \
# Date
# 2020-03-25 00:00:00-04:00  24.370001  25.240000  22.910000  24.49  618725
# 2020-03-26 00:00:00-04:00  24.250000  24.650000  22.379999  22.60  633877
# 2020-03-27 00:00:00-04:00  23.290001  23.440001  20.879999  21.51  603124
# 2020-03-30 00:00:00-04:00  20.930000  20.930000  19.270000  20.09  758711
# 2020-03-31 00:00:00-04:00  20.230000  21.889999  20.010000  20.48  660082
#
#                            Dividends  Stock Splits
# Date
# 2020-03-25 00:00:00-04:00        0.0           0.0
# 2020-03-26 00:00:00-04:00        0.0           0.0
# 2020-03-27 00:00:00-04:00        0.0           0.0
# 2020-03-30 00:00:00-04:00        0.0           0.0
# 2020-03-31 00:00:00-04:00        0.0           0.0
